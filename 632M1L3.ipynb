# %% [markdown]
# <a href="https://colab.research.google.com/github/worldart/worldart_jupyternotebook/blob/main/632M1L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import yfinance as yf

# Getting historical market data from SPY (ETF) (SPY)
df = yf.download("SPY", start="2000-01-01", end="2022-01-01", auto_adjust=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df["Ret"] = df["Close"].pct_change()

name = "Ret"
df["Ret10_i"] = (
    df[name].rolling(10).apply(lambda x: 100 * ((np.prod(1 + x)) ** (1 / 10) - 1))
)
df["Ret25_i"] = (
    df[name].rolling(25).apply(lambda x: 100 * ((np.prod(1 + x)) ** (1 / 25) - 1))
)
df["Ret60_i"] = (
    df[name].rolling(60).apply(lambda x: 100 * ((np.prod(1 + x)) ** (1 / 60) - 1))
)
df["Ret120_i"] = (
    df[name].rolling(120).apply(lambda x: 100 * ((np.prod(1 + x)) ** (1 / 120) - 1))
)
df["Ret240_i"] = (
    df[name].rolling(240).apply(lambda x: 100 * ((np.prod(1 + x)) ** (1 / 240) - 1))
)

# %%
df
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker             SPY         SPY         SPY         SPY       SPY
# Date
# 2000-01-03   91.887817   93.664763   90.900626   93.664763   8164300
# 2000-01-04   88.294411   91.019059   88.225307   90.683414   8089800
# 2000-01-05   88.452354   89.419802   86.714897   88.412867  12177900
# 2000-01-06   87.030785   89.400044   87.030785   88.215414   6227200
# 2000-01-07   92.085228   92.085228   88.491851   88.649801   8066500
# ...                ...         ...         ...         ...       ...
# 2021-12-27  452.783508  452.830932  447.802757  447.850181  56808600
# 2021-12-28  452.413483  454.253991  451.645026  453.219896  47274600
# 2021-12-29  452.992249  454.016848  451.512256  452.517891  54503000
# 2021-12-30  451.739899  454.434244  451.275038  453.419113  55329000
# 2021-12-31  450.601410  452.403962  450.326304  451.246558  65237400
#
# Price            Ret   Ret10_i   Ret25_i   Ret60_i  Ret120_i  Ret240_i
# Ticker
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 -0.039106       NaN       NaN       NaN       NaN       NaN
# 2000-01-05  0.001789       NaN       NaN       NaN       NaN       NaN
# 2000-01-06 -0.016072       NaN       NaN       NaN       NaN       NaN
# 2000-01-07  0.058076       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.014152  0.172776  0.077671  0.183143  0.083921  0.100753
# 2021-12-28 -0.000817  0.253750  0.081564  0.162054  0.090063  0.101875
# 2021-12-29  0.001279  0.335815  0.097970  0.185859  0.082273  0.105461
# 2021-12-30 -0.002765  0.152642  0.081580  0.163955  0.076983  0.101044
# 2021-12-31 -0.002520  0.216101  0.060807  0.152819  0.077726  0.094259
#
# [5536 rows x 11 columns]

# %%
df2= df

# %%
df2 = df.dropna()
df.tail(10)
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2021-12-17  436.285309  440.905544  434.568138  437.879142  135511600
# 2021-12-20  431.646149  432.044593  428.003088  431.171791  107134800
# 2021-12-21  439.311707  439.454008  432.907884  435.089916   69806300
# 2021-12-22  443.704285  443.818126  438.856339  439.055589   58890200
# 2021-12-23  446.465027  447.973479  444.605555  444.709899   56439700
# 2021-12-27  452.783508  452.830932  447.802757  447.850181   56808600
# 2021-12-28  452.413483  454.253991  451.645026  453.219896   47274600
# 2021-12-29  452.992249  454.016848  451.512256  452.517891   54503000
# 2021-12-30  451.739899  454.434244  451.275038  453.419113   55329000
# 2021-12-31  450.601410  452.403962  450.326304  451.246558   65237400
#
# Price            Ret   Ret10_i   Ret25_i   Ret60_i  Ret120_i  Ret240_
# Price            Ret   Ret10_i   Ret25_i   Ret60_i  Ret120_i  Ret240_i
# Ticker
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04 -0.039106       NaN       NaN       NaN       NaN       NaN
# 2000-01-05  0.001789       NaN       NaN       NaN       NaN       NaN
# 2000-01-06 -0.016072       NaN       NaN       NaN       NaN       NaN
# 2000-01-07  0.058076       NaN       NaN       NaN       NaN       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.014152  0.172776  0.077671  0.183143  0.083921  0.100753
# 2021-12-28 -0.000817  0.253750  0.081564  0.162054  0.090063  0.101875
# 2021-12-29  0.001279  0.335815  0.097970  0.185859  0.082273  0.105461
# 2021-12-30 -0.002765  0.152642  0.081580  0.163955  0.076983  0.101044
# 2021-12-31 -0.002520  0.216101  0.060807  0.152819  0.077726  0.094259
#
# [5536 rows x 11 columns]

# %%
del df["Open"]
del df["Close"]
del df["High"]
del df["Low"]
del df["Volume"]


df = df.dropna()
df
# Out:
# Price            Ret   Ret10_i   Ret25_i   Ret60_i  Ret120_i  Ret240_i
# Ticker
# Date
# 2000-12-13 -0.013697  0.200755 -0.217314 -0.116105 -0.046836 -0.024438
# 2000-12-14 -0.012739  0.159496 -0.178981 -0.125108 -0.068171 -0.013161
# 2000-12-15 -0.022587 -0.064343 -0.255052 -0.137632 -0.081034 -0.023423
# 2000-12-18  0.013362 -0.016349 -0.103726 -0.145522 -0.072308 -0.011144
# 2000-12-19 -0.020368 -0.543482 -0.154741 -0.167910 -0.081540 -0.043231
# ...              ...       ...       ...       ...       ...       ...
# 2021-12-27  0.014152  0.172776  0.077671  0.183143  0.083921  0.100753
# 2021-12-28 -0.000817  0.253750  0.081564  0.162054  0.090063  0.101875
# 2021-12-29  0.001279  0.335815  0.097970  0.185859  0.082273  0.105461
# 2021-12-30 -0.002765  0.152642  0.081580  0.163955  0.076983  0.101044
# 2021-12-31 -0.002520  0.216101  0.060807  0.152819  0.077726  0.094259
#
# [5296 rows x 6 columns]

# %%
df["Ret25"] = df["Ret25_i"].shift(-25)
df = df.dropna()
df.tail(10)
# Out:
# /tmp/ipython-input-468970398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ret25"] = df["Ret25_i"].shift(-25)
# Price            Ret   Ret10_i   Ret25_i   Ret60_i  Ret120_i  Ret240_i  \
# Ticker
# Date
# 2021-11-11  0.000323  0.118281  0.222904  0.096176  0.089688  0.109046
# 2021-11-12  0.007547  0.173277  0.260371  0.106139  0.097812  0.107645
# 2021-11-15  0.000342  0.159489  0.290889  0.093487  0.096444  0.106911
# 2021-11-16  0.003958  0.158638  0.316624  0.085466  0.099300  0.108672
# 2021-11-17 -0.002429  0.073349  0.292457  0.078763  0.095781  0.104078
# 2021-11-18  0.003397  0.060235  0.239157  0.080923  0.099345  0.106351
# 2021-11-19 -0.001788  0.007681  0.201566  0.087814  0.096541  0.104385
# 2021-11-22 -0.002815 -0.029040  0.178421  0.068264  0.097291  0.106967
# 2021-11-23  0.001326  0.017318  0.152938  0.063156  0.090802  0.107656
# 2021-11-24  0.002670  0.124830  0.147916  0.070076  0.093836  0.109258
#
# Price          Ret25
# Ticker
# Date
# 2021-11-11 -0.019749
# 2021-11-12 -0.092544
# 2021-11-15 -0.023542
# 2021-11-16  0.000453
# 2021-11-17  0.034999
# 2021-11-18  0.077671
# 2021-11-19  0.081564
# 2021-11-22  0.097970
# 2021-11-23  0.081580
# 2021-11-24  0.060807

# %%
df["Output"] = df["Ret25"].apply(np.sign)
del df["Ret25"]
df.tail(10)
# Out:
# /tmp/ipython-input-2862441356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Output"] = df["Ret25"].apply(np.sign)
# Price            Ret   Ret10_i   Ret25_i   Ret60_i  Ret120_i  Ret240_i Output
# Ticker
# Date
# 2021-11-11  0.000323  0.118281  0.222904  0.096176  0.089688  0.109046   -1.0
# 2021-11-12  0.007547  0.173277  0.260371  0.106139  0.097812  0.107645   -1.0
# 2021-11-15  0.000342  0.159489  0.290889  0.093487  0.096444  0.106911   -1.0
# 2021-11-16  0.003958  0.158638  0.316624  0.085466  0.099300  0.108672    1.0
# 2021-11-17 -0.002429  0.073349  0.292457  0.078763  0.095781  0.104078    1.0
# 2021-11-18  0.003397  0.060235  0.239157  0.080923  0.099345  0.106351    1.0
# 2021-11-19 -0.001788  0.007681  0.201566  0.087814  0.096541  0.104385    1.0
# 2021-11-22 -0.002815 -0.029040  0.178421  0.068264  0.097291  0.106967    1.0
# 2021-11-23  0.001326  0.017318  0.152938  0.063156  0.090802  0.107656    1.0
# 2021-11-24  0.002670  0.124830  0.147916  0.070076  0.093836  0.109258    1.0

# %%
df.describe()
# Out:
# Price           Ret      Ret10_i      Ret25_i      Ret60_i     Ret120_i  \
# Ticker
# count   5271.000000  5271.000000  5271.000000  5271.000000  5271.000000
# mean       0.000382     0.031692     0.030981     0.029921     0.028931
# std        0.012244     0.339498     0.212192     0.131787     0.096484
# min       -0.109423    -3.067444    -1.622892    -0.875641    -0.493507
# 25%       -0.004300    -0.108998    -0.056106    -0.023079    -0.013857
# 50%        0.000725     0.069002     0.064760     0.054810     0.046547
# 75%        0.005855     0.212352     0.152113     0.109303     0.084388
# max        0.145197     1.973281     0.997341     0.559837     0.359181
#
# Price      Ret240_i       Output
# Ticker
# count   5271.000000  5271.000000
# mean       0.027804     0.309050
# std        0.071045     0.951136
# min       -0.282909    -1.000000
# 25%        0.006765    -1.000000
# 50%        0.045128     1.000000
# 75%        0.069933     1.000000
# max        0.231672     1.000000

# %%
X, y = df.iloc[:, 0:-1], df.iloc[:, -1]
print(X.shape, y.shape)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=int(len(y) * 0.5), shuffle=False
)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5271, 6) (5271,)
# (2636, 6) (2635, 6) (2636,) (2635,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 7))
plt.plot(
    df.index,
    np.cumsum(y),
    label="Cumulative ups (+1) and downs (-1) of SPY over 25 days",
)
legend = plt.legend(loc="upper left")
# plt.ylim([-1.25,1.25])
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_input = MinMaxScaler(feature_range=(-1, 1))
scaler_input.fit(X_train)
X_train = scaler_input.transform(X_train)
X_test = scaler_input.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# all parameters not specified are set to their defaults
logisticRegr = LogisticRegression()
logisticRegr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
predictions = logisticRegr.predict(X_test)

# %%
# Use score method to get accuracy of model
score = logisticRegr.score(X_test, y_test)
print(score)
# Out:
# 0.720303605313093

# %%
# import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics

cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9, 9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=0.5, square=True, cmap="Blues_r")
plt.ylabel("Actual label")
plt.xlabel("Predicted label")
all_sample_title = "Accuracy Score: {0}".format(score)
plt.title(all_sample_title, size=15);

# %%
from sklearn import metrics

fpr, tpr, thresholds = metrics.roc_curve(y_test, predictions)
roc_auc = metrics.auc(fpr, tpr)
display = metrics.RocCurveDisplay(
    fpr=fpr, tpr=tpr, roc_auc=roc_auc, estimator_name="estimation"
)
display.plot()
plt.show()
